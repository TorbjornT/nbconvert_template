# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

mpl.rcParams['savefig.dpi'] = 200
mpl.rcParams['figure.figsize'] = (4,2.4)
mpl.rcParams['savefig.pad_inches'] = 0

# %% [markdown]
# # First part

# %% [markdown]
# And then some fancy words.
#
# ## Sub-section
#
# And even more lorem ipsum.

# %%
x = np.linspace(0, 3*np.pi,500)
y1 = np.sin(x)
y2 = 0.5*np.cos(x) + 0.5
fig, ax = plt.subplots()
ax.plot(x,y1,label='sin')
ax.plot(x,y2,label='cos')
ax.legend(loc='best')
ax.set_xlim((0,10))
ax.set_ylim((-1.1,1.1))
fig.tight_layout()
fig.savefig('demofig.pdf')

# %% [markdown]
# ![This is the caption for the figure above. Adding a label for cross reference. \label{fig:demo}](demofig)

# %% [markdown]
# We can refer to this figure, with \ref{fig:demo}, though the cross reference of course doesn't work inside the notebook.

# %%
# !jupyter nbconvert --to latex --template ../scrartcl.tplx sample-notebook.ipynb
# Out:
# [NbConvertApp] Converting notebook sample-notebook.ipynb to latex
# [NbConvertApp] Support files will be in sample-notebook_files/
# [NbConvertApp] Making directory sample-notebook_files
# [NbConvertApp] Writing 1101 bytes to sample-notebook.tex
